# %%
#!pip install citipy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import API key
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 644

# %%
# Testing Sandbox
units = "imperial"
test = "grand river south east"

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?"
query_url = url + "appid=" + api_key + "&units" + units + "&q=" + test

response = requests.get(query_url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "cod": "404",
#     "message": "city not found"
# }

# %% [markdown]
# ## Perform API Calls

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?"

# Build partial query URL and save config information
query_url = f"{url}appid={api_key}&units={units}&q="
units = "imperial"

# Set-up lists to hold response data
lat = []
lng = []
cloud = []
country = []
date = []
humidity = []
maxTemp = []
wind = []

# %%
# Create dataframe and columns to store city weather conditions
cityWeatherDF = pd.DataFrame({"City": cities})                       
cityWeatherDF["Cloudiness"] = ""
cityWeatherDF["Country"] = ""
cityWeatherDF["Date"] = ""
cityWeatherDF["Humidity"] = "" 
cityWeatherDF["Latitude"] = ""
cityWeatherDF["Longitude"] = ""
cityWeatherDF["Max Temp"] = ""
cityWeatherDF["Wind Speed"] = ""
#cityWeatherDF.head()

# %%
# Loop through all cities to capture data
for index, row in cityWeatherDF.iterrows():
    
    # Incorporate exception handling to skip cities that are missing a data point.
    try:
    
        # Get city name from cityWeatherDF 
        city = row["City"]
    
        # Assemble URL and make API request for each city
        response = requests.get(query_url + city).json()
    
        # Get specific column data 
        cloud = response['clouds']['all']
        country = response['sys']['country']
        date = response['dt']
        humidity = response['main']['humidity']
        lat = response['coord']['lat']
        lng = response['coord']['lon']
        maxTemp = response['main']['temp_max']
        wind = response['wind']['speed']
        
        # Add row information to the city weather dataframe
        cityWeatherDF.at[index, 'Cloudiness'] = cloud
        cityWeatherDF.at[index, 'Country'] = country
        cityWeatherDF.at[index, 'Date'] = date
        cityWeatherDF.at[index, 'Humidity'] = humidity
        cityWeatherDF.at[index, 'Latitude'] = lat
        cityWeatherDF.at[index, 'Longitude'] = lng
        cityWeatherDF.at[index, 'Max Temp'] = maxTemp
        cityWeatherDF.at[index, 'Wind Speed'] = wind
        
    # Skip cities with missing data point and continue looping
    except (KeyError, IndexError) as error:
        print(f"{city} Missing field/result... skipping.") 
        pass 
 
 # Print dataframe
cityWeatherDF.head(10)
# Out:
# envira Missing field/result... skipping.
# bengkulu Missing field/result... skipping.
# galiwinku Missing field/result... skipping.
# taolanaro Missing field/result... skipping.
# belushya guba Missing field/result... skipping.
# barbar Missing field/result... skipping.
# barentsburg Missing field/result... skipping.
# amderma Missing field/result... skipping.
# mys shmidta Missing field/result... skipping.
# hurghada Missing field/result... skipping.
# tumannyy Missing field/result... skipping.
# illoqqortoormiut Missing field/result... skipping.
# suao Missing field/result... skipping.
# khonuu Missing field/result... skipping.
# phan rang Missing field/result... skipping.
# vaitupu Missing field/result... skipping.
# tapaua Missing field/result... skipping.
# nizhneyansk Missing field/result... skipping.
# karaul Missing field/result... skipping.
# tanggu Missing field/result... skipping.
# kamenskoye Missing field/result... skipping.
# aflu Missing field/result... skipping.
# grand river south east Missing field/result... skipping.
# lolua Missing field/result... skipping.
# sentyabrskiy Missing field/result... skipping.
# samusu Missing field/result... skipping.
# opobo Missing field/result... skipping.
# bolungarvik Missing field/result... skipping.
# attawapiskat Missing field/result... skipping.
# korla Missing field/result... skipping.
# kashi Missing field/result... skipping.
# odweyne Missing field/result... skipping.
# samalaeulu Missing field/result... skipping.
# marcona Missing field/result... skipping.
# olafsvik Missing field/result... skipping.
# pokrovsk-uralskiy Missing field/result... skipping.
# yeletskiy Missing field/result... skipping.
# manzil tamim Missing field/result... skipping.
# georgiu-dezh Missing field/result... skipping.
# scottsburgh Missing field/result... skipping.
# tsentralnyy Missing field/result... skipping.
# bolshiye uki Missing field/result... skipping.
# makung Missing field/result... skipping.
# mudyuga Missing field/result... skipping.
# tsihombe Missing field/result... skipping.
# tasbuget Missing field/result... skipping.
# maloshuyka Missing field/result... skipping.
# ciras Missing field/result... skipping.
# barawe Missing field/result... skipping.
# cheuskiny Missing field/result... skipping.
# kacergine Missing field/result... skipping.
# chagda Missing field/result... skipping.
# asau Missing field/result... skipping.
# bury saint edmunds Missing field/result... skipping.
# longlac Missing field/result... skipping.
# bargal Missing field/result... skipping.
# kazalinsk Missing field/result... skipping.
# wahran Missing field/result... skipping.
# palabuhanratu Missing field/result... skipping.
# burkhala Missing field/result... skipping.
#              City Cloudiness Country        Date Humidity Latitude Longitude  \
# 0           kapaa         40      US  1530809760       83    22.08   -159.32
# 1         rikitea         32      PF  1530812834      100   -23.12   -134.97
# 2  port elizabeth         75      US  1530811500       66    39.31    -74.98
# 3   makakilo city          1      US  1530809820       73    21.35   -158.09
# 4   rabo de peixe         40      PT  1530811800       83     37.8    -25.58
# 5          itoman         75      JP  1530810000       83    26.12    127.67
# 6    punta arenas         90      CL  1530810000       80   -53.16    -70.91
# 7          anadyr          8      RU  1530810000       76    64.73    177.51
# 8    norman wells         75      CA  1530810000       67    65.28   -126.83
# 9          marawi         44      PH  1530812835      100        8    124.29
#
#   Max Temp Wind Speed
# 0       77      13.87
# 1     72.8      13.11
# 2     89.6      11.41
# 3     78.8        4.7
# 4     71.6      14.99
# 5     80.6      19.46
# 6     35.6      12.75
# 7     55.4       2.24
# 8     62.6      18.34
# 9     66.5       0.58

# %%
# Temperature (F) vs. Latitude

# Convert column objects to numeric/float data type
cityWeatherDF["Latitude"] = pd.to_numeric(cityWeatherDF["Latitude"])
cityWeatherDF["Max Temp"] = pd.to_numeric(cityWeatherDF["Max Temp"])
cityWeatherDF["Humidity"] = pd.to_numeric(cityWeatherDF["Humidity"])
cityWeatherDF["Cloudiness"] = pd.to_numeric(cityWeatherDF["Cloudiness"])
cityWeatherDF["Wind Speed"] = pd.to_numeric(cityWeatherDF["Wind Speed"])
#print(cityWeatherDF.dtypes)

# Create the scatter plot, legend and axes titles
plt.scatter(cityWeatherDF["Latitude"], cityWeatherDF["Max Temp"], facecolors="darkblue", edgecolors="black",  alpha=0.75)

plt.title("City Latitude vs. Max Temperature (07/05/18)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.savefig("Images/Temperature.png")
plt.show()

# %%
# Humidity (%) vs. Latitude

# Create the scatter plot, legend and axes titles
plt.scatter(cityWeatherDF["Latitude"], cityWeatherDF["Humidity"], facecolors="darkblue", edgecolors="black",  alpha=0.75)

plt.title("City Latitude vs. Humidity (07/05/18)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.savefig("Images/Humidity.png")
plt.show()

# %%
# Cloudiness (%) vs. Latitude

# Create the scatter plot, legend and axes titles
plt.scatter(cityWeatherDF["Latitude"], cityWeatherDF["Cloudiness"], facecolors="darkblue", edgecolors="black",  alpha=0.75)

plt.title("City Latitude vs. Cloudiness (07/05/18)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.savefig("Images/Cloudiness.png")
plt.show()

# %%
# Wind Speed (mph) vs. Latitude

# Create the scatter plot, legend and axes titles
plt.scatter(cityWeatherDF["Latitude"], cityWeatherDF["Wind Speed"], facecolors="darkblue", edgecolors="black",  alpha=0.75)

plt.title("City Latitude vs. Wind Speed (07/05/18)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.savefig("Images/Wind Speed.png")
plt.show()
